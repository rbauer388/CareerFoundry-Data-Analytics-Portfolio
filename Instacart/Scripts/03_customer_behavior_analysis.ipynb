# %%
# 3.

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
df_orders_products_combined = pd.read_pickle(r'C:\Users\rbaue\Desktop\Instacart\Prepared Data\orders_products_combined.pkl')

# %%
# 4.

# %%
df_orders_products_combined.shape
# Out:
# (32434489, 12)

# %%
# 5.

# %%
df_prods_checked = pd.read_csv(r'C:\Users\rbaue\Desktop\Instacart\Prepared Data\prods_checked.csv', index_col = False)

# %%
df_prods_checked.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
df_merged_large = pd.read_pickle(r'C:\Users\rbaue\Desktop\Instacart\Prepared Data\merged_large.pkl')

# %%
df_merged_large.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             0           0   2539329        1             1
# 2             0           0   2539329        1             1
# 3             0           0   2539329        1             1
# 4             0           0   2539329        1             1
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                   2                  8                     NaN         196
# 1                   2                  8                     NaN       14084
# 2                   2                  8                     NaN       12427
# 3                   2                  8                     NaN       26088
# 4                   2                  8                     NaN       26405
#
#    add_to_cart_order  reordered _merge
# 0                  1          0   both
# 1                  2          0   both
# ...

# %% [markdown]
# I realized I had those Unnamed: 0.1 and Unnamed: 0 columns from saving multiple times with index included, so I asked Chat GPT for code to remove them

# %%
df_merged_large = df_merged_large.loc[:, ~df_merged_large.columns.str.contains("^Unnamed")]
df_prods_checked = df_prods_checked.loc[:, ~df_prods_checked.columns.str.contains("^Unnamed")]

# %%
df_merged_large.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both

# %%
df_merged_large = df_merged_large.loc[:, ~df_merged_large.columns.str.contains("^Unnamed")]

# %%
df_merged_large.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both

# %%
df_prods_checked = df_prods_checked.loc[:, ~df_prods_checked.columns.str.contains("^Unnamed")]

# %%
df_prods_checked.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
df_merged_large = df_merged_large.drop(columns=['_merge'], errors='ignore')
df_prods_checked = df_prods_checked.drop(columns=['_merge'], errors='ignore')

# %%
df_merged_large_prods_checked = df_prods_checked.merge(df_merged_large, on = 'product_id', indicator = True)

# %%
# 6.

# %%
df_merged_large_prods_checked.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   3139998      138            28                   6                 11
# 1   1977647      138            30                   6                 17
# 2    389851      709             2                   0                 21
# 3    652770      764             1                   3                 13
# 4   1813452      764             3                   4                 17
#
#    days_since_prior_order  add_to_cart_order  reordered _merge
# ...

# %%
df_merged_large_prods_checked['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
# 7.

# %%
path = r'C:\Users\rbaue\Desktop\Instacart'

# %%
df_merged_large_prods_checked.to_pickle(os.path.join(path, 'Prepared Data', 'merged_large_prods_checked.pkl'))

# %%
df_merged_large_prods_checked.to_pickle(os.path.join(path, 'Prepared Data', 'ords_prods_merge.pkl'))

# %% [markdown]
# ## Table of Contents
#
# 1. Import Libraries and Load Data
# 2. Explore Dataset Shape and Department-Level Order Behavior
# 3. Compare Exercise and Full Dataset Results
# 4. Create Loyalty Flags Based on Order History
# 5. Analyze Price Differences by Loyalty Group
# 6. Calculate Average Orders per User
# 7. Measure Order Regularity Using Median Days Since Prior Order
# 8. Create Customer Spending Segments
# 9. Save Final Prepared Dataset

# %%
# 1.

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Import datasets
ords_prods_merge = pd.read_pickle(r'C:\Users\rbaue\Desktop\Instacart\Prepared Data\ords_prods_merge3.pkl')

# %%
# 2.

# %%
ords_prods_merge.shape
# Out:
# (32404859, 20)

# %%
ords_prods_merge.groupby('department_id').agg({'order_number':['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %%
# 3.

# %% [markdown]
# The results are pretty similar. Each mean value is slightly different, but there are no major differences. This is because the subset we ran this process on in the exercise was sufficiently large (one millions rows) to be a representative sample.

# %%
# 4.

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
# 5.

# %%
ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %% [markdown]
# It looks like there's a bit of a difference in the average price of a product the different customers purchase, but it's pretty small.

# %%
# 6.

# %%
ords_prods_merge['avg_price'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.mean)
# Out:
# C:\Users\rbaue\AppData\Local\Temp\ipykernel_16864\1180104323.py:1: FutureWarning: The provided callable <function mean at 0x000002C015603920> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   ords_prods_merge['avg_price'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.mean)

# %%
ords_prods_merge.head(15)
# Out:
#     product_id                product_name  aisle_id  department_id  prices  \
# 0            1  Chocolate Sandwich Cookies        61             19     5.8
# 1            1  Chocolate Sandwich Cookies        61             19     5.8
# 2            1  Chocolate Sandwich Cookies        61             19     5.8
# 3            1  Chocolate Sandwich Cookies        61             19     5.8
# 4            1  Chocolate Sandwich Cookies        61             19     5.8
# 5            1  Chocolate Sandwich Cookies        61             19     5.8
# 6            1  Chocolate Sandwich Cookies        61             19     5.8
# 7            1  Chocolate Sandwich Cookies        61             19     5.8
# 8            1  Chocolate Sandwich Cookies        61             19     5.8
# 9            1  Chocolate Sandwich Cookies        61             19     5.8
# 10           1  Chocolate Sandwich Cookies        61             19     5.8
# 11           1  Chocolate Sandwich Cookies        61             19     5.8
# 12           1  Chocolate Sandwich Cookies        61             19     5.8
# 13           1  Chocolate Sandwich Cookies        61             19     5.8
# 14           1  Chocolate Sandwich Cookies        61             19     5.8
#
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    3139998      138            28                   6                 11
# 1    1977647      138            30                   6                 17
# 2     389851      709             2                   0                 21
# 3     652770      764             1                   3                 13
# 4    1813452      764             3                   4                 17
# 5    1701441      777            16                   1                  7
# 6    1871483      825             3                   2                 14
# 7    1290456      910            12                   3                 10
# 8     369558     1052            10                   1                 20
# 9     589712     1052            15                   1                 12
# 10   1798115     1379             1                   5                 11
# 11    497193     1480            36                   3                 13
# 12   1727826     1480            38                   4                 13
# 13   2694698     1480            39                   2                 12
# 14   3171753     1494             6                   3                 10
#
#     ...  add_to_cart_order  reordered  _merge     busiest_day  \
# 0   ...                  5          0    both  Regularly busy
# 1   ...                  1          1    both  Regularly busy
# 2   ...                 20          0    both     Busiest day
# 3   ...                 10          0    both  Regularly busy
# 4   ...                 11          1    both      Least busy
# 5   ...                  7          0    both  Regularly busy
# 6   ...                  2          0    both  Regularly busy
# 7   ...                  1          0    both  Regularly busy
# 8   ...                  1          0    both  Regularly busy
# 9   ...                  2          1    both  Regularly busy
# 10  ...                  1          0    both  Regularly busy
# 11  ...                  1          0    both  Regularly busy
# 12  ...                  3          1    both      Least busy
# 13  ...                  4          1    both  Regularly busy
# 14  ...                  8          0    both  Regularly busy
#
#        busiest_days  most_orders   busiest_hours max_order      loyalty_flag  \
# 0    Regularly busy  Most orders  Average orders        32  Regular customer
# 1    Regularly busy  Most orders  Average orders        32  Regular customer
# 2       Busiest day  Most orders  Average orders         5      New customer
# 3   Least busy days  Most orders  Average orders         3      New customer
# 4        Least busy  Most orders  Average orders         3      New customer
# 5    Regularly busy  Most orders  Average orders        26  Regular customer
# 6    Regularly busy  Most orders  Average orders         9      New customer
# 7   Least busy days  Most orders     Most orders        12  Regular customer
# 8    Regularly busy  Most orders  Average orders        20  Regular customer
# 9    Regularly busy  Most orders  Average orders        20  Regular customer
# 10   Regularly busy  Most orders  Average orders        10      New customer
# 11  Least busy days  Most orders  Average orders        43    Loyal customer
# 12       Least busy  Most orders  Average orders        43    Loyal customer
# 13   Regularly busy  Most orders  Average orders        43    Loyal customer
# 14  Least busy days  Most orders     Most orders        13  Regular customer
#
#     avg_price
# 0   14.790541
# 1   14.790541
# 2    3.062500
# 3    2.017241
# 4    2.017241
# 5   14.964602
# 6    4.939394
# 7    7.700000
# 8   10.958333
# 9   10.958333
# 10   5.181818
# 11  21.448980
# 12  21.448980
# 13  21.448980
# 14   6.803797
#
# [15 rows x 21 columns]

# %%
ords_prods_merge['average_spend']=ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)
# Out:
# C:\Users\rbaue\AppData\Local\Temp\ipykernel_16864\3899763501.py:1: FutureWarning: The provided callable <function mean at 0x000002C015603920> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   ords_prods_merge['average_spend']=ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
ords_prods_merge.loc[ords_prods_merge['average_spend']<10,'spender_flag']='Low_spender'

ords_prods_merge.loc[ords_prods_merge['average_spend']>= 10, 'spender_flag'] = 'High_spender'

# %%
ords_prods_merge['spender_flag'].value_counts(dropna = False)
# Out:
# spender_flag
# Low_spender     31770614
# High_spender      634245
# Name: count, dtype: int64

# %%
ords_prods_merge.head(10)
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
# 5           1  Chocolate Sandwich Cookies        61             19     5.8
# 6           1  Chocolate Sandwich Cookies        61             19     5.8
# 7           1  Chocolate Sandwich Cookies        61             19     5.8
# 8           1  Chocolate Sandwich Cookies        61             19     5.8
# 9           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   3139998      138            28                   6                 11
# 1   1977647      138            30                   6                 17
# 2    389851      709             2                   0                 21
# 3    652770      764             1                   3                 13
# 4   1813452      764             3                   4                 17
# 5   1701441      777            16                   1                  7
# 6   1871483      825             3                   2                 14
# 7   1290456      910            12                   3                 10
# 8    369558     1052            10                   1                 20
# 9    589712     1052            15                   1                 12
#
#    ...     busiest_days  most_orders   busiest_hours max_order  \
# 0  ...   Regularly busy  Most orders  Average orders        32
# 1  ...   Regularly busy  Most orders  Average orders        32
# 2  ...      Busiest day  Most orders  Average orders         5
# 3  ...  Least busy days  Most orders  Average orders         3
# 4  ...       Least busy  Most orders  Average orders         3
# 5  ...   Regularly busy  Most orders  Average orders        26
# 6  ...   Regularly busy  Most orders  Average orders         9
# 7  ...  Least busy days  Most orders     Most orders        12
# 8  ...   Regularly busy  Most orders  Average orders        20
# 9  ...   Regularly busy  Most orders  Average orders        20
#
#        loyalty_flag  avg_price average_spend spender_flag  med_dspo  \
# 0  Regular customer  14.790541      6.935811  Low_spender       8.0
# 1  Regular customer  14.790541      6.935811  Low_spender       8.0
# 2      New customer   3.062500      7.930208  Low_spender       8.0
# 3      New customer   2.017241      4.972414  Low_spender       9.0
# 4      New customer   2.017241      4.972414  Low_spender       9.0
# 5  Regular customer  14.964602      6.935398  Low_spender      11.0
# 6      New customer   4.939394      5.957576  Low_spender      20.0
# 7  Regular customer   7.700000      6.680000  Low_spender       6.0
# 8  Regular customer  10.958333      7.162500  Low_spender      10.0
# 9  Regular customer  10.958333      7.162500  Low_spender      10.0
#
#     order_regularity
# 0  Frequent customer
# 1  Frequent customer
# 2  Frequent customer
# 3  Frequent customer
# 4  Frequent customer
# 5   Regular customer
# 6   Regular customer
# 7  Frequent customer
# 8  Frequent customer
# 9  Frequent customer
#
# [10 rows x 25 columns]

# %%
# 7.

# %%
ords_prods_merge['med_dspo'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)
# Out:
# C:\Users\rbaue\AppData\Local\Temp\ipykernel_16864\793941765.py:1: FutureWarning: The provided callable <function median at 0x000002C01574E480> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   ords_prods_merge['med_dspo'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
ords_prods_merge.head(5)
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   3139998      138            28                   6                 11
# 1   1977647      138            30                   6                 17
# 2    389851      709             2                   0                 21
# 3    652770      764             1                   3                 13
# 4   1813452      764             3                   4                 17
#
#    ...     busiest_days  most_orders   busiest_hours max_order  \
# 0  ...   Regularly busy  Most orders  Average orders        32
# 1  ...   Regularly busy  Most orders  Average orders        32
# 2  ...      Busiest day  Most orders  Average orders         5
# 3  ...  Least busy days  Most orders  Average orders         3
# 4  ...       Least busy  Most orders  Average orders         3
#
#        loyalty_flag  avg_price average_spend spender_flag  med_dspo  \
# 0  Regular customer  14.790541      6.935811  Low_spender       8.0
# 1  Regular customer  14.790541      6.935811  Low_spender       8.0
# 2      New customer   3.062500      7.930208  Low_spender       8.0
# 3      New customer   2.017241      4.972414  Low_spender       9.0
# 4      New customer   2.017241      4.972414  Low_spender       9.0
#
#     order_regularity
# 0  Frequent customer
# 1  Frequent customer
# 2  Frequent customer
# 3  Frequent customer
# 4  Frequent customer
#
# [5 rows x 25 columns]

# %%
ords_prods_merge.loc[ords_prods_merge['med_dspo'] > 20, 'order_regularity'] = 'Non-frequent customer'
ords_prods_merge.loc[(ords_prods_merge['med_dspo'] <= 20) & (ords_prods_merge['med_dspo'] > 10), 'order_regularity'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['med_dspo'] <= 10, 'order_regularity'] = 'Frequent customer'

# %%
ords_prods_merge['order_regularity'].value_counts(dropna = False)
# Out:
# order_regularity
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# NaN                             5
# Name: count, dtype: int64

# %%
ords_prods_merge.head(10)
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
# 5           1  Chocolate Sandwich Cookies        61             19     5.8
# 6           1  Chocolate Sandwich Cookies        61             19     5.8
# 7           1  Chocolate Sandwich Cookies        61             19     5.8
# 8           1  Chocolate Sandwich Cookies        61             19     5.8
# 9           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   3139998      138            28                   6                 11
# 1   1977647      138            30                   6                 17
# 2    389851      709             2                   0                 21
# 3    652770      764             1                   3                 13
# 4   1813452      764             3                   4                 17
# 5   1701441      777            16                   1                  7
# 6   1871483      825             3                   2                 14
# 7   1290456      910            12                   3                 10
# 8    369558     1052            10                   1                 20
# 9    589712     1052            15                   1                 12
#
#    ...     busiest_days  most_orders   busiest_hours max_order  \
# 0  ...   Regularly busy  Most orders  Average orders        32
# 1  ...   Regularly busy  Most orders  Average orders        32
# 2  ...      Busiest day  Most orders  Average orders         5
# 3  ...  Least busy days  Most orders  Average orders         3
# 4  ...       Least busy  Most orders  Average orders         3
# 5  ...   Regularly busy  Most orders  Average orders        26
# 6  ...   Regularly busy  Most orders  Average orders         9
# 7  ...  Least busy days  Most orders     Most orders        12
# 8  ...   Regularly busy  Most orders  Average orders        20
# 9  ...   Regularly busy  Most orders  Average orders        20
#
#        loyalty_flag  avg_price average_spend spender_flag  med_dspo  \
# 0  Regular customer  14.790541      6.935811  Low_spender       8.0
# 1  Regular customer  14.790541      6.935811  Low_spender       8.0
# 2      New customer   3.062500      7.930208  Low_spender       8.0
# 3      New customer   2.017241      4.972414  Low_spender       9.0
# 4      New customer   2.017241      4.972414  Low_spender       9.0
# 5  Regular customer  14.964602      6.935398  Low_spender      11.0
# 6      New customer   4.939394      5.957576  Low_spender      20.0
# 7  Regular customer   7.700000      6.680000  Low_spender       6.0
# 8  Regular customer  10.958333      7.162500  Low_spender      10.0
# 9  Regular customer  10.958333      7.162500  Low_spender      10.0
#
#     order_regularity
# 0  Frequent customer
# 1  Frequent customer
# 2  Frequent customer
# 3  Frequent customer
# 4  Frequent customer
# 5   Regular customer
# 6   Regular customer
# 7  Frequent customer
# 8  Frequent customer
# 9  Frequent customer
#
# [10 rows x 25 columns]

# %%
# 9.

# %%
path = r'C:\Users\rbaue\Desktop\Instacart'

# %%
ords_prods_merge.to_pickle(os.path.join(path, 'Prepared Data', 'ords_prods_merge4.pkl'))

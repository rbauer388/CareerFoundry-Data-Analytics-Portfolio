# %% [markdown]
# ## Table of Contents
# 1. [Import Libraries](#import-libraries)
# 2. [Load Datasets](#load-datasets)
# 3. [Inspect Orders and Prior Orders Data](#inspect-orders-and-prior-orders-data)
# 4. [Merge Orders with Prior Products](#merge-orders-with-prior-products)
# 5. [Validate Merge Results](#validate-merge-results)
# 6. [Export Merged Dataset](#export-merged-dataset)
# 7. [Verify Final Dataset Shape](#verify-final-dataset-shape)

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Import datasets
df_ords = pd.read_csv(r'C:\Users\rbaue\Desktop\Instacart\Prepared Data\ords_checked.csv', index_col = False)
df_ords_prior = pd.read_csv(r'C:\Users\rbaue\Desktop\Instacart\Original Data\orders_products_prior.csv', index_col = False)

# %%
df_ords.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             1           1   2398795        1             2
# 2             2           2    473747        1             3
# 3             3           3   2254736        1             4
# 4             4           4    431534        1             5
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order
# 0                   2                  8                     NaN
# 1                   3                  7                    15.0
# 2                   3                 12                    21.0
# 3                   4                  7                    29.0
# 4                   4                 15                    28.0

# %%
# Check the output
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
df_ords.shape
# Out:
# (3421083, 8)

# %%
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)

# %%
df_merged_large.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             0           0   2539329        1             1
# 2             0           0   2539329        1             1
# 3             0           0   2539329        1             1
# 4             0           0   2539329        1             1
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                   2                  8                     NaN         196
# 1                   2                  8                     NaN       14084
# 2                   2                  8                     NaN       12427
# 3                   2                  8                     NaN       26088
# 4                   2                  8                     NaN       26405
#
#    add_to_cart_order  reordered _merge
# 0                  1          0   both
# 1                  2          0   both
# ...

# %%
df_merged_large['_merge'].value_counts()
# Out:
# _merge
# both          32434489
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
path = r'C:\Users\rbaue\Desktop\Instacart'

# %%
df_merged_large.to_pickle(os.path.join(path, 'Prepared Data', 'orders_products_combined.pk1'))

# %%
# 2.

# %%
path = r'C:\Users\rbaue\Desktop\Instacart'

# %%
df_merged_large.to_pickle(os.path.join(path, 'Prepared Data', 'merged_large.pkl'))

# %%
df_merged_large.shape
# Out:
# (32434489, 12)

# %%
df_merged_large.shape()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df_merged_large.shape()
#
# NameError: name 'df_merged_large' is not defined
